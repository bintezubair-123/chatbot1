# %%
# !pip install mlxtend
# !pip install pandas 
# !pip install pprintpp

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import association_rules, apriori

# %%
sales_reciepts = pd.read_csv ('dataset/201904 sales reciepts.csv')
sales_reciepts.head()
# Out:
#    transaction_id transaction_date transaction_time  sales_outlet_id  \
# 0               7       2019-04-01         12:04:43                3
# 1              11       2019-04-01         15:54:39                3
# 2              19       2019-04-01         14:34:59                3
# 3              32       2019-04-01         16:06:04                3
# 4              33       2019-04-01         19:18:37                3
#
#    staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# 0        12          558          N      1             1          52
# 1        17          781          N      1             1          27
# 2        17          788          Y      1             1          46
# 3        12          683          N      1             1          23
# 4        17           99          Y      1             1          34
#
#    quantity  line_item_amount  unit_price promo_item_yn
# 0         1              2.50        2.50             N
# 1         2              7.00        3.50             N
# 2         2              5.00        2.50             N
# 3         2              5.00        2.50             N
# 4         1              2.45        2.45             N

# %%
product = pd.read_csv ('dataset/product.csv')
product.head()
# Out:
#    product_id    product_group product_category       product_type  \
# 0           1  Whole Bean/Teas     Coffee beans      Organic Beans
# 1           2  Whole Bean/Teas     Coffee beans  House blend Beans
# 2           3  Whole Bean/Teas     Coffee beans     Espresso Beans
# 3           4  Whole Bean/Teas     Coffee beans     Espresso Beans
# 4           5  Whole Bean/Teas     Coffee beans      Gourmet Beans
#
#                     product  \
# 0       Brazilian - Organic
# 1  Our Old Time Diner Blend
# 2            Espresso Roast
# 3      Primo Espresso Roast
# 4    Columbian Medium Roast
#
#                                  product_description unit_of_measure  \
# 0     It's like Carnival in a cup. Clean and smooth.           12 oz
# 1  Out packed blend of beans that is reminiscent ...           12 oz
# 2          Our house blend for a good espresso shot.            1 lb
# 3   Our primium single source of hand roasted beans.            1 lb
# 4           A smooth cup of coffee any time of day.             1 lb
#
#    current_wholesale_price current_retail_price tax_exempt_yn promo_yn  \
# 0                    14.40              $18.00              Y        N
# 1                    14.40              $18.00              Y        N
# 2                    11.80              $14.75              Y        N
# 3                    16.36              $20.45              Y        N
# 4                    12.00              $15.00              Y        N
#
#   new_product_yn
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Merge Data

# %%
dataset=pd.merge(sales_reciepts[['transaction_id','transaction_date','sales_outlet_id','customer_id','product_id','quantity']]
,product[['product_id','product_category','product']],on='product_id',how='left')
dataset.head()
# Out:
#    transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 0               7       2019-04-01                3          558          52
# 1              11       2019-04-01                3          781          27
# 2              19       2019-04-01                3          788          46
# 3              32       2019-04-01                3          683          23
# 4              33       2019-04-01                3           99          34
#
#    quantity product_category                      product
# 0         1              Tea    Traditional Blend Chai Rg
# 1         2           Coffee                 Brazilian Lg
# 2         2              Tea        Serenity Green Tea Rg
# 3         2           Coffee  Our Old Time Diner Blend Rg
# 4         1           Coffee     Jamaican Coffee River Sm

# %% [markdown]
# ## Remove Sizes

# %%
#Unique number of products
dataset['product'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset['product'].nunique()
#
# NameError: name 'dataset' is not defined

# %%
dataset['product']=dataset['product'].str.replace('Rg','')
dataset['product']=dataset['product'].str.replace('Lg','')
dataset['product']=dataset['product'].str.replace('Sm','')

# %%
dataset.head()
# Out:
#    transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 0               7       2019-04-01                3          558          52
# 1              11       2019-04-01                3          781          27
# 2              19       2019-04-01                3          788          46
# 3              32       2019-04-01                3          683          23
# 4              33       2019-04-01                3           99          34
#
#    quantity product_category                    product
# 0         1              Tea    Traditional Blend Chai
# 1         2           Coffee                 Brazilian
# 2         2              Tea        Serenity Green Tea
# 3         2           Coffee  Our Old Time Diner Blend
# 4         1           Coffee     Jamaican Coffee River

# %%
print(dataset['product'].unique())
# Out:
# ['Traditional Blend Chai ' 'Brazilian ' 'Serenity Green Tea '
#  'Our Old Time Diner Blend ' 'Jamaican Coffee River ' 'Ethiopia '
#  'English Breakfast ' 'Sustainably Grown Organic ' 'Earl Grey '
#  'Cappuccino' 'Espresso shot' 'Cappuccino ' 'Latte' 'Dark chocolate '
#  'Columbian Medium Roast ' 'Oatmeal Scone' 'Morning Sunrise Chai '
#  'Peppermint ' 'Jumbo Savory Scone' 'Lemon Grass ' 'Latte '
#  'Chocolate Chip Biscotti' 'Spicy Eye Opener Chai ' 'Ginger Biscotti'
#  'Chocolate Croissant' 'Hazelnut Biscotti' 'Cranberry Scone'
#  'Scottish Cream Scone ' 'Croissant' 'Almond Croissant' 'Ginger Scone'
#  'Ouro Brasileiro shot' 'Organic Decaf Blend' 'Chocolate syrup'
#  'Peppermint' 'Ethiopia' 'Hazelnut syrup' 'Carmel syrup'
#  'English Breakfast' 'Sugar Free Vanilla syrup' 'Our Old Time Diner Blend'
#  'Jamacian Coffee River' 'Spicy Eye Opener Chai'
#  'Sustainably Grown Organic' 'Dark chocolate'
#  'Guatemalan Sustainably Grown' 'Civet Cat' 'Serenity Green Tea'
#  'Chili Mayan' 'Primo Espresso Roast' 'Brazilian - Organic'
#  'Morning Sunrise Chai' 'Earl Grey' 'I Need My Bean! Diner mug'
#  'Traditional Blend Chai' 'Espresso Roast' 'Columbian Medium Roast'
#  'I Need My Bean! T-shirt' 'I Need My Bean! Latte cup' 'Lemon Grass']

# %%
products_to_take = ['Cappuccino', 'Latte', 'Espresso shot',  \
                     'Dark chocolate','Sugar Free Vanilla syrup', 'Chocolate syrup',\
                    'Carmel syrup', 'Hazelnut syrup', 'Ginger Scone',  \
                    'Chocolate Croissant', 'Jumbo Savory Scone', 'Cranberry Scone', 'Hazelnut Biscotti',\
                    'Croissant', 'Almond Croissant', 'Oatmeal Scone', 'Chocolate Chip Biscotti',\
                    'Ginger Biscotti',\
                   ]

# %%
dataset=dataset[dataset['product'].isin(products_to_take)]

# %%
dataset['product'].nunique()
# Out:
# 18

# %%
dataset[['product','product_category']].drop_duplicates().reset_index(drop=True)
# Out:
#                      product    product_category
# 0                 Cappuccino              Coffee
# 1              Espresso shot              Coffee
# 2                      Latte              Coffee
# 3              Oatmeal Scone              Bakery
# 4         Jumbo Savory Scone              Bakery
# 5    Chocolate Chip Biscotti              Bakery
# 6            Ginger Biscotti              Bakery
# 7        Chocolate Croissant              Bakery
# 8          Hazelnut Biscotti              Bakery
# 9            Cranberry Scone              Bakery
# 10                 Croissant              Bakery
# 11          Almond Croissant              Bakery
# 12              Ginger Scone              Bakery
# 13           Chocolate syrup            Flavours
# 14            Hazelnut syrup            Flavours
# 15              Carmel syrup            Flavours
# 16  Sugar Free Vanilla syrup            Flavours
# 17            Dark chocolate  Packaged Chocolate

# %% [markdown]
# ## Clean Transactions

# %%
dataset['transaction'] = dataset['transaction_id'].astype(str) +"_"+  dataset['customer_id'].astype(str)

# %%
num_of_items_for_each_transaction = dataset['transaction'].value_counts().reset_index()
valid_transactions = num_of_items_for_each_transaction[(num_of_items_for_each_transaction['count']>1)]['transaction'].tolist()
dataset = dataset[dataset['transaction'].isin(valid_transactions)]

# %%
dataset.shape
# Out:
# (7346, 9)

# %% [markdown]
# ## Product Trends

# %%
dataset["product_category"].value_counts()
# Out:
# product_category
# Bakery                3459
# Flavours              1972
# Coffee                1896
# Packaged Chocolate      19
# Name: count, dtype: int64

# %%
dataset['product'].value_counts()
# Out:
# product
# Cappuccino                  645
# Latte                       631
# Espresso shot               620
# Chocolate Croissant         601
# Sugar Free Vanilla syrup    530
# Chocolate syrup             506
# Carmel syrup                486
# Hazelnut syrup              450
# Ginger Scone                381
# Croissant                   330
# Jumbo Savory Scone          319
# Almond Croissant            316
# Chocolate Chip Biscotti     315
# Cranberry Scone             308
# Hazelnut Biscotti           307
# Oatmeal Scone               293
# Ginger Biscotti             289
# Dark chocolate               19
# Name: count, dtype: int64

# %% [markdown]
# # Popularity Recommendation Engine

# %%
popularity_recommendation = dataset.groupby(['product','product_category']).count().reset_index()

# %%
popularity_recommendation = popularity_recommendation[['product','product_category','transaction_id']]
popularity_recommendation = popularity_recommendation.rename(columns = {'transaction_id':'number_of_transactions'})

# %%
popularity_recommendation.to_csv('api/recommendation_objects/popularity_recommendation.csv',index=False)

# %% [markdown]
# # Apriori Recommendation Engine

# %%
train_basket = (dataset.groupby(['transaction','product'])['product'].count().reset_index(name ='Count'))
train_basket.head(10)
# Out:
#   transaction             product  Count
# 0   1001_8306          Cappuccino      1
# 1   1001_8306        Carmel syrup      1
# 2      1002_0        Carmel syrup      1
# 3      1002_0       Espresso shot      1
# 4      1002_0        Ginger Scone      1
# 5   1004_5383     Chocolate syrup      1
# 6   1004_5383               Latte      1
# 7      1005_0  Jumbo Savory Scone      2
# 8      1005_0               Latte      1
# 9   1005_5559               Latte      1

# %%
my_basket = train_basket.pivot_table(index='transaction', columns='product', values='Count', aggfunc='sum').fillna(0)
my_basket.head()
# Out:
# product      Almond Croissant  Cappuccino  Carmel syrup  \
# transaction
# 1001_8306                 0.0         1.0           1.0
# 1002_0                    0.0         0.0           1.0
# 1004_5383                 0.0         0.0           0.0
# 1005_0                    0.0         0.0           0.0
# 1005_5559                 0.0         0.0           0.0
#
# product      Chocolate Chip Biscotti  Chocolate Croissant  Chocolate syrup  \
# transaction
# 1001_8306                        0.0                  0.0              0.0
# 1002_0                           0.0                  0.0              0.0
# 1004_5383                        0.0                  0.0              1.0
# 1005_0                           0.0                  0.0              0.0
# 1005_5559                        0.0                  0.0              0.0
#
# product      Cranberry Scone  Croissant  Dark chocolate  Espresso shot  \
# transaction
# 1001_8306                0.0        0.0             0.0            0.0
# 1002_0                   0.0        0.0             0.0            1.0
# 1004_5383                0.0        0.0             0.0            0.0
# 1005_0                   0.0        0.0             0.0            0.0
# 1005_5559                0.0        0.0             0.0            0.0
#
# product      Ginger Biscotti  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1001_8306                0.0           0.0                0.0             0.0
# 1002_0                   0.0           1.0                0.0             0.0
# 1004_5383                0.0           0.0                0.0             0.0
# 1005_0                   0.0           0.0                0.0             0.0
# 1005_5559                0.0           0.0                0.0             0.0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1001_8306                   0.0    0.0            0.0
# 1002_0                      0.0    0.0            0.0
# 1004_5383                   0.0    1.0            0.0
# 1005_0                      2.0    1.0            0.0
# 1005_5559                   0.0    1.0            0.0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1001_8306                         0.0
# 1002_0                            0.0
# 1004_5383                         0.0
# 1005_0                            0.0
# 1005_5559                         1.0

# %%
def encode_units(x):
  if x <= 0:
    return 0
  if x >= 0:
    return 1

my_basket_sets = my_basket.applymap(encode_units)
my_basket_sets.head(10)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11152\1756069047.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_basket_sets = my_basket.applymap(encode_units)
# product      Almond Croissant  Cappuccino  Carmel syrup  \
# transaction
# 1001_8306                   0           1             1
# 1002_0                      0           0             1
# 1004_5383                   0           0             0
# 1005_0                      0           0             0
# 1005_5559                   0           0             0
# 1006_0                      1           1             0
# 1007_8375                   0           0             0
# 1008_0                      0           0             1
# 1009_5183                   0           0             0
# 100_0                       0           1             1
#
# product      Chocolate Chip Biscotti  Chocolate Croissant  Chocolate syrup  \
# transaction
# 1001_8306                          0                    0                0
# 1002_0                             0                    0                0
# 1004_5383                          0                    0                1
# 1005_0                             0                    0                0
# 1005_5559                          0                    0                0
# 1006_0                             0                    0                0
# 1007_8375                          0                    0                0
# 1008_0                             0                    0                0
# 1009_5183                          0                    0                0
# 100_0                              0                    0                1
#
# product      Cranberry Scone  Croissant  Dark chocolate  Espresso shot  \
# transaction
# 1001_8306                  0          0               0              0
# 1002_0                     0          0               0              1
# 1004_5383                  0          0               0              0
# 1005_0                     0          0               0              0
# 1005_5559                  0          0               0              0
# 1006_0                     0          0               0              1
# 1007_8375                  0          0               0              1
# 1008_0                     0          0               0              0
# 1009_5183                  0          0               0              0
# 100_0                      0          1               0              0
#
# product      Ginger Biscotti  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1001_8306                  0             0                  0               0
# 1002_0                     0             1                  0               0
# 1004_5383                  0             0                  0               0
# 1005_0                     0             0                  0               0
# 1005_5559                  0             0                  0               0
# 1006_0                     0             0                  0               0
# 1007_8375                  0             0                  0               1
# 1008_0                     0             1                  0               0
# 1009_5183                  0             0                  0               0
# 100_0                      0             0                  1               0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1001_8306                     0      0              0
# 1002_0                        0      0              0
# 1004_5383                     0      1              0
# 1005_0                        1      1              0
# 1005_5559                     0      1              0
# 1006_0                        0      0              0
# 1007_8375                     0      0              0
# 1008_0                        0      1              0
# 1009_5183                     0      1              0
# 100_0                         0      0              0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1001_8306                           0
# 1002_0                              0
# 1004_5383                           0
# 1005_0                              0
# 1005_5559                           1
# 1006_0                              0
# 1007_8375                           0
# 1008_0                              0
# 1009_5183                           1
# 100_0                               0

# %%
frequent_items = apriori(my_basket_sets, min_support = 0.05,use_colnames = True)
frequent_items.head()
# Out:
# C:\Users\lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                   itemsets
# 0  0.140163         (Almond Croissant)
# 1  0.282365               (Cappuccino)
# 2  0.219674             (Carmel syrup)
# 3  0.133028  (Chocolate Chip Biscotti)
# 4  0.165138      (Chocolate Croissant)

# %%
rules_basket = association_rules(frequent_items, metric = "lift", min_threshold = 1)
rules_basket.head()
# Out:
#          antecedents        consequents  antecedent support  \
# 0     (Carmel syrup)       (Cappuccino)            0.219674
# 1       (Cappuccino)     (Carmel syrup)            0.282365
# 2  (Chocolate syrup)       (Cappuccino)            0.223242
# 3       (Cappuccino)  (Chocolate syrup)            0.282365
# 4   (Hazelnut syrup)       (Cappuccino)            0.199796
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.282365  0.076453    0.348028  1.232546               1.0
# 1            0.219674  0.076453    0.270758  1.232546               1.0
# 2            0.282365  0.086646    0.388128  1.374561               1.0
# 3            0.223242  0.086646    0.306859  1.374561               1.0
# 4            0.282365  0.071356    0.357143  1.264827               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.014424    1.100714       0.241785  0.179641   0.091499    0.309393
# 1  0.014424    1.070051       0.262907  0.179641   0.065465    0.309393
# 2  0.023611    1.172851       0.350811  0.206813   0.147377    0.347494
# 3  0.023611    1.120636       0.379713  0.206813   0.107649    0.347494
# 4  0.014940    1.116321       0.261656  0.173697   0.104200    0.304925

# %%
# Save Rules Basket
rules_basket.to_pickle('rules_basket.pkl')

# %%
# Get Example Recommendations
rules_basket[rules_basket['antecedents']=={'Latte'}].sort_values('confidence',ascending=False).head(50)
# Out:
#    antecedents                 consequents  antecedent support  \
# 27     (Latte)  (Sugar Free Vanilla syrup)            0.281346
# 10     (Latte)              (Carmel syrup)            0.281346
# 16     (Latte)           (Chocolate syrup)            0.281346
# 24     (Latte)            (Hazelnut syrup)            0.281346
# 13     (Latte)       (Chocolate Croissant)            0.281346
# 18     (Latte)                 (Croissant)            0.281346
#
#     consequent support   support  confidence      lift  representativity  \
# 27            0.231906  0.085627    0.304348  1.312375               1.0
# 10            0.219674  0.082569    0.293478  1.335973               1.0
# 16            0.223242  0.074924    0.266304  1.192898               1.0
# 24            0.199796  0.073904    0.262681  1.314746               1.0
# 13            0.165138  0.051988    0.184783  1.118961               1.0
# 18            0.141182  0.050459    0.179348  1.270326               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 27  0.020381    1.104135       0.331206  0.200238   0.094313    0.336789
# 10  0.020765    1.104462       0.349934  0.197320   0.094582    0.334674
# 16  0.012116    1.058693       0.225011  0.174377   0.055439    0.300960
# 24  0.017692    1.085289       0.333118  0.181477   0.078586    0.316290
# 13  0.005527    1.024098       0.147935  0.131783   0.023531    0.249799
# 18  0.010738    1.046506       0.296110  0.135616   0.044439    0.268374

# %% [markdown]
# # Save in Json Format

# %%
product_categories = dataset[['product','product_category']].drop_duplicates().set_index('product').to_dict()['product_category']

# %%
recommendations_json = {}

antecedents = rules_basket['antecedents'].unique()
for antecedent in antecedents:
    df_rec = rules_basket[rules_basket['antecedents']==antecedent]
    df_rec = df_rec.sort_values('confidence',ascending=False)
    key = "_".join(antecedent)
    recommendations_json[key] = []
    for _, row in df_rec.iterrows():
        rec_objects =row['consequents']
        for rec_object in rec_objects:
            already_exists = False
            for current_rec_object in recommendations_json[key]:
                if rec_object == current_rec_object['product']:
                    already_exists=True
            if already_exists:
                continue
            
            rec = {'product':rec_object, 
                   'product_category':product_categories[rec_object],
                   'confidence': row['confidence']
                  }
            recommendations_json[key].append(rec)

# %%
import pprint
pprint.pp(recommendations_json)
# Out:
# {'Carmel syrup': [{'product': 'Latte',
#                    'product_category': 'Coffee',
#                    'confidence': 0.37587006960556846},
#                   {'product': 'Espresso shot',
#                    'product_category': 'Coffee',
#                    'confidence': 0.3712296983758701},
#                   {'product': 'Cappuccino',
#                    'product_category': 'Coffee',
#                    'confidence': 0.3480278422273782}],
#  'Cappuccino': [{'product': 'Sugar Free Vanilla syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.32671480144404336},
#                 {'product': 'Chocolate syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.3068592057761733},
#                 {'product': 'Carmel syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.27075812274368233},
#                 {'product': 'Hazelnut syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.25270758122743686}],
#  'Chocolate syrup': [{'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.3881278538812785},
#                      {'product': 'Espresso shot',
#                       'product_category': 'Coffee',
#                       'confidence': 0.3561643835616438},
#                      {'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.3356164383561644}],
#  'Hazelnut syrup': [{'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.37244897959183676},
#                     {'product': 'Latte',
#                      'product_category': 'Coffee',
#                      'confidence': 0.36989795918367346},
#                     {'product': 'Cappuccino',
#                      'product_category': 'Coffee',
#                      'confidence': 0.35714285714285715}],
#  'Sugar Free Vanilla syrup': [{'product': 'Cappuccino',
#                                'product_category': 'Coffee',
#                                'confidence': 0.3978021978021978},
#                               {'product': 'Latte',
#                                'product_category': 'Coffee',
#                                'confidence': 0.3692307692307692},
#                               {'product': 'Espresso shot',
#                                'product_category': 'Coffee',
#                                'confidence': 0.35604395604395606}],
#  'Espresso shot': [{'product': 'Sugar Free Vanilla syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.29670329670329676},
#                    {'product': 'Carmel syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.29304029304029305},
#                    {'product': 'Chocolate syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.28571428571428575},
#                    {'product': 'Hazelnut syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.26739926739926745}],
#  'Latte': [{'product': 'Sugar Free Vanilla syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.3043478260869565},
#            {'product': 'Carmel syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.29347826086956524},
#            {'product': 'Chocolate syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.266304347826087},
#            {'product': 'Hazelnut syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.26268115942028986},
#            {'product': 'Chocolate Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.18478260869565216},
#            {'product': 'Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.17934782608695654}],
#  'Chocolate Croissant': [{'product': 'Latte',
#                           'product_category': 'Coffee',
#                           'confidence': 0.31481481481481477}],
#  'Croissant': [{'product': 'Latte',
#                 'product_category': 'Coffee',
#                 'confidence': 0.3574007220216607}]}

# %%
import json
with open('api/recommendation_objects/apriori_recommendations.json', 'w') as json_file:
    json.dump(recommendations_json, json_file)
